# %% [markdown]
# # Aspect Based Sentiment Analysis

# %% [markdown]
# ## Importing data

# %%
import pandas as pd

df = pd.read_csv("train.csv")

# %%
df.shape
# Out:
# (4000, 3)

# %%
df.head(10)
# Out:
#                                                 text        aspect  label
# 0    can you check whether its cancelled completely?     cancelled      1
# 1  cannot rely on both milk delivery and grocery ...          Milk      0
# 2  I get no notification, however the app is real...  notification      0
# 3  Love this app, but would love it even more if ...          view      1
# 4        it does not let me load a clip on the scene          load      0
# 5  i love notion as a tool, but the mobile just t...         tool,      2
# 6                      unlimited yearly at $216/year        yearly      1
# 7  some times missing to deliver, some times diff...      deliver,      0
# 8  Would love the ability to “un-delete” deleted ...         tasks      1
# 9                      please add this basic feature        Please      2

# %% [markdown]
# ## Checking Null Values

# %%
df.isna().sum()
# Out:
# text      0
# aspect    0
# label     0
# dtype: int64

# %%
print((df['label'] == 0).sum())
print((df['label'] == 1).sum())
print((df['label'] == 2).sum())
# Out:
# 1680
# 1294
# 1026

# %% [markdown]
# ## Preprocessing the data

# %%
import re
import string

def remove_URL(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r"", text)

# https://stackoverflow.com/questions/34293875/how-to-remove-punctuation-marks-from-a-string-in-python-3-x-using-translate/34294022
def remove_punct(text):
    translator = str.maketrans("", "", string.punctuation)
    return text.translate(translator)

string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# ## Removal of punctuations and URLs

# %%
df["text"] = df.text.map(remove_URL) # map(lambda x: remove_URL(x))
df["text"] = df.text.map(remove_punct)

# %%
df.head(10)
# Out:
#                                                 text        aspect  label
# 0     can you check whether its cancelled completely     cancelled      1
# 1  cannot rely on both milk delivery and grocery ...          Milk      0
# 2  I get no notification however the app is reall...  notification      0
# 3  Love this app but would love it even more if G...          view      1
# 4        it does not let me load a clip on the scene          load      0
# 5  i love notion as a tool but the mobile just ta...         tool,      2
# 6                        unlimited yearly at 216year        yearly      1
# 7  some times missing to deliver some times diffe...      deliver,      0
# 8  Would love the ability to “undelete” deleted t...         tasks      1
# 9                      please add this basic feature        Please      2

# %% [markdown]
# ## Removing Stopwords

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# Stop Words: A stop word is a commonly used word (such as “the”, “a”, “an”, “in”) that a search engine
# has been programmed to ignore, both when indexing entries for searching and when retrieving them 
# as the result of a search query.
stop = set(stopwords.words("english"))


def remove_stopwords(s):
    s = s.lower()
    # Change 't to 'not'
    s = re.sub(r"\'t", " not", s)
    # Remove @name
    s = re.sub(r'(@.*?)[\s]', ' ', s)
    # Isolate and remove punctuations except '?'
    s = re.sub(r'([\'\"\.\(\)\!\?\\\/\,])', r' \1 ', s)
    s = re.sub(r'[^\w\s\?]', ' ', s)
    # Remove some special characters
    s = re.sub(r'([\;\:\|•«\n])', ' ', s)
    # Remove stopwords except 'not' and 'can'
    s = " ".join([word for word in s.split()
                  if word not in stopwords.words('english')
                  or word in ['not', 'can']])
    # Remove trailing whitespace
    s = re.sub(r'\s+', ' ', s).strip()
    
    return s
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df["text"] = df.text.map(remove_stopwords)

# %%
df.head(10)
# Out:
#                                                 text        aspect  label
# 0             can check whether cancelled completely     cancelled      1
# 1            cannot rely milk delivery grocery items          Milk      0
# 2           get notification however app really fine  notification      0
# 3  love app would love even gantt charts calendar...          view      1
# 4                            not let load clip scene          load      0
# 5        love notion tool mobile takes way long load         tool,      2
# 6                           unlimited yearly 216year        yearly      1
# 7  times missing deliver times different orders d...      deliver,      0
# 8  would love ability undelete deleted tasks app ...         tasks      1
# 9                           please add basic feature        Please      2

# %%
df['text'] = df['text'] + " " + df['aspect']

# %%
X = list(df['text'])
X

# %%
y = list(df['label'])
y

# %% [markdown]
# ## Splitting data for training and validation

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.1, random_state = 20)

# %%
print('Training Data : ' + str(len(X_train)))
print('Validation Data : ' + str(len(X_val)))
# Out:
# Training Data : 3600
# Validation Data : 400

# %%
X_train
# Out:
# ['promised timely delivery timely',
#  'would like able help edit things edit',
#  'subscription end next month subscription',
#  'would hate owner lose notes can avoided notes',
#  'spent 2 hours organizing notionhq notes organizing',
#  'since not linux app add vote change Linux',
#  'system showing order delivered not getting delivery fraud happening delivery,',
#  'heard app podcast app',
#  'timely delivery convenience delivery',
#  'comparison windows programme slow startup slow process need high internet speed stop save page not working offline windows programme',
#  'notion website application awesome find app not easy use notion website application',
#  'best app daily tasks notes scheduling notes',
#  'app life saver app',
#  'uploaded image logo section logo',
#  'not fast options considering power flexibility beyond worth flexibility,',
#  'delete workspace ipad ipad',
#  'everytime launch workspace team happens workspace',
#  'ianaitchison roamresearch notionhq notion support suggested import may fail note whose attribu support',
#  'constantly thanking sharing gratitude computer helps sharing',
#  'also started charging delivery charges without intimation delivery charges',
#  'anytime try start video trimmer error pops pops',
#  'trial 30 days end cannt back free plan forced buy prmium option diffeent plan explanation bad experience Buy',
#  'remove music video draft remove',
#  'digital marketing agency app used task management 3 years marketing',
#  'really like app app',
#  'send products charged products',
#  'please improve mobile app version mobile app',
#  'one best productivity apps apps',
#  'want cancel request refund cancel',
#  'means can use premium template export without payment pay',
#  'might get effects transitions scenes transition',
#  'evernote Evernote',
#  'mean not charged vat charged',
#  'home partnership future learning education funder strategy group grantmakers thriving youth Learning,',
#  'can ask invoice since first time subscribed first time',
#  'fresh items good packing Fresh items,',
#  'good app mobile desktop versions desktop versions',
#  'new iphone broke took old 5 could not use asana iPhone',
#  'took 20 account kindly refund cancel subscription can not find cancel',
#  'amazingly well designed well detailed easy interface much choices Amazingly',
#  'looking rejoin possibly business plan business plan.',
#  'well really like app although first bit confused overwhelmed use app',
#  'reason giving 4 star app details mentioned app work offline well offline',
#  'okay see free 14 day trial business unlimited plans free',
#  'nice app app,',
#  'know basic spreadsheet relational database can gather data view quickly view',
#  'would like cancel free trial however not seem button free',
#  'can anyone tell adjust size texts texts',
#  'subscribes business package subscribes',
#  'using browser apple phone phone',
#  'day delivery shift another day delivery',
#  'want know current plan paid plan',
#  'use notion everyday task management note taking resources recipes goals etc Notion',
#  'using notion two months Notion',
#  'middle screen trying swipe element menu slides middle user can feel lagging inconvenience using appweb get excited features set work app/web',
#  'app slow page takes much time load App',
#  'improve quality products quality',
#  'getting stats right side bar youtube side bar',
#  'app great funtions posibilities slow hell update App',
#  'faster resolution queries issues queries',
#  'app powerful app',
#  'please fix bug updated get can see archive button updated',
#  'sidebar section displays parent pages within workspace workspace',
#  'best app team management team',
#  '32 bit windows desktop app would highly appreciated desktop app',
#  'notionapi notionhq please add columnsblocks can placed next ios app iOS',
#  'cant use anymore asana ipad 4 ios 1034 iOS',
#  'get better service deliver not charge 20 rs deliveryb deliver',
#  'look black screen screen',
#  'option changing order available changing order',
#  'would nice possibility widgets home screen quickly add pagenote widgets',
#  'starting love notion mobile app needs improvement app',
#  'notion desktop app best productivity tool app totally sucks desktop app',
#  'alexandbooks thanks sharing alexandbooks 10th point would recommend using notionhq personal rolo sharing',
#  'added someone team collaborate projects not see share project projects,',
#  'copy paste could not achieve copy',
#  'bundle size not whole singlepage performance story performance',
#  'not native zoom feature zoom',
#  'last update hasnt become userfriendly update',
#  'go istock website search find picture videot possible find plataform website',
#  'maintain proper temparature milk pocket n vegetables also not fresh vegetables',
#  'like going back time using app app.',
#  'told guy bought defective bought',
#  'remove delivery charges Delivery charges.',
#  'happy notion moment learned hands app',
#  'like functional useful app app',
#  'app runs nicely useful tracking many things however option formulas fields options need use something else tracking',
#  'switched unlimited promo code good plans plans.',
#  'release mac app mac',
#  'finally another thing need sorted sync devices notes done notion ipad not shown open iphone sync',
#  'want boost sales functions boom want manage marketing functions bang want handle service functions bam function system run business can organized tracked measured aidtable spreadsheets flex can even automate workflows blocks airtable automation tool feature encourage person working company build app airtable much can register free account go templates search okr tracking create 3 key results improve business Search',
#  'can adjust duration text box start beginning scene text',
#  'delivery fee membership fee high Delivery',
#  'website version works fine website version works fine',
#  'order marked delivered delivered',
#  'sure can apply code get trial plan plan',
#  'love asana omg ios app not best IOS',
#  'got one link embed cannot edit document edit',
#  'issue scrolling app freeze not scroll can press links scroll slowly trying catch close reopen fix will',
#  'already listed link sent listed',
#  'notion highly configurable application bringing together lists basic databases workflow stubs etc stubs',
#  'app not load offline viewing notes App',
#  'well manually adjust duration media text adding scene every time scene',
#  'vegetables poor quality completely rotten quality,',
#  'please focus customers service service',
#  'piece notionhqs approach design came back brink makes great read design',
#  'fairly simple customise adding position fixed css customise',
#  'share google contact loging using gmail google',
#  'can not show edit notes offline edit',
#  'timely delivery availability stocks delivery',
#  'can not export videos believe export',
#  'change project colors custom colors',
#  'app not upto mark app',
#  'invideo create text box template template.',
#  'addition delivery fee time lockdown people already distressed worst step taken supr daily mgmt delivery',
#  'toggle control contorl number list control list',
#  'difficult type every time option use touch pen ie apple pencilspeniam pleasurable make app Pen',
#  'deleted app app.',
#  'account manager literally yelled meeting failure explaining things properly zero patience client questions even functioning computer share screen computer',
#  'delivery inconsistent action 2 complaints delivery Delivery',
#  'bit hard navigate lists mobile interface mobile',
#  'ok tried export seemed get stuck 99 stuck',
#  'ipad pro 11 2020 iPad',
#  'asana app pushed hard site emails nearly useless ipad due fact details section screen limited small strip 13rd width screen emails',
#  'using business not let add international tax number tax',
#  'tried like app complicated use app,',
#  'prompt delivery professional delivery partners products good quality exceptions redressed timely delivery,',
#  'nocodeluc notionhq invent new shortcut bullet points tho bullet',
#  'professional plan get option upgrade higher plan wish use premium emdia upgrade',
#  'extremely prompt quick resolution addressing greviance &Quick resolution in addressing greviance.',
#  'features access 3500 curated templates full access image library full access standard video library 120 istock images videos free access creator clubs premium templates istock',
#  'hello tried windows desktop app web app chrome edge Desktop',
#  'first started using airtable mac Mac',
#  'plenty issues notifications force magic link login app login',
#  'supr bag still not provided Supr bag',
#  'incredible slow start useless wait much slow start',
#  'start explore engage app gets really easy truly life saver app,',
#  'app amazing app',
#  'card details purged card',
#  'can see screen overlay spinning circle never goes away not able click page screen,',
#  'recommend editing computer app using phone app things like checking planner app,',
#  'tasks dont show blank line Tasks',
#  'airtable great simple use sheet format actually works many devices even older oss ios 8 one thats amazing sheet',
#  'can guys add apple pencil support ipad writing like goodnotes add voice recording like notablity add voice',
#  'proper delivery since week delivery',
#  'foss apps better job better ui UI.',
#  'first loading time opening app needs improve next instead click lot buttons highlight phrase clicking color click choose color would efficient highlight phrase one click highlighted like striking wordsphrase phrase',
#  'android app really sucks Android app',
#  'hi andy part team paid plan glassworks paid plan',
#  'remove acess membership service fee service fee.',
#  'got notion devices homeowners policy said download app install notion devices app',
#  'quality delivery time delivery check delivery person delivering product properly delivering quality product delivery',
#  'see card charged 20 card',
#  'reduce delivery charges make delivery reliable delivery charges,',
#  'increased using browser layout generally broken around native way layout',
#  'restored mobile file uploads various cloud services back five stars file',
#  'app working great sure improves productivity productivity',
#  'already set pages small text mobile app text large can barely see lines text,',
#  'delivery product offers pricing Delivery',
#  'allows quickly check pages wish would load faster load',
#  'recently installed app app.',
#  'nah guys keeps sending codes opening links really love idea app codes',
#  'love notion app slow notion,',
#  'new account created account',
#  'one best pm database apps Database',
#  'may able choose thumbnail put video onto youtube anyway thumbnail',
#  'service bad stopped complaining use Service',
#  'currently not happy many missed deliveries deliveries.',
#  'hare not showing either workspace workspace?',
#  'separate location like can google doc link Google',
#  'update miezu mx6 app not starred app',
#  'not user friendly user friendly.',
#  'charged credit card credit card',
#  'better app category App',
#  'want buy lifetime deal lifetime',
#  'great app app',
#  'trust milk packet one color delivered milk packet color raised issue saying milk',
#  'go ahead add vote prioritize better copypaste support using ios paste',
#  'forgot password also lost access email account used account',
#  'overall app really good using med school taking organizing notes app',
#  'created webinar clubhouse database notionhq database',
#  'add another vote notionhq using yt organization awhile organization',
#  'able search name clicp search',
#  'concept delivery charge service fee much delivery charge',
#  'android app not fast snappy using web mac app android app',
#  'powerful tool still lacks offline mode offline mode.',
#  'hi brandon cannot download video download',
#  'can not get previews load whether istock videos yur library preview',
#  'order not getting delivered since last 23 times shows delivered Order',
#  'never started black screen comes automaticaly running first image image',
#  'set fit type fit transparent transparent',
#  'polish language dark motif language',
#  'timely delivery reasonable prices good support customer service team customer service team',
#  'okay see free 14 day trial business unlimited plans unlimited',
#  'plain copy text option even app app.',
#  'stock availability quality veges fruits pricing service fees Stock availability,',
#  'apke product ki price product',
#  'hey notionhq possible embed apk file document file',
#  'great app missing one killer feature make noteorganization app ipad app,',
#  'free fantastic product can use chronical add pix etc free',
#  'update changed way tablesviews scroll sideways leaving descriptive header row ill ok eventually since see goal scroll',
#  'great app students app',
#  'change way delete image image.',
#  'constantly notifications badges asana app even though tasks complete notifications',
#  'please provide free delivery products free delivery',
#  'introduction delivery fees per pack milk delivery paves way customers buy directly shops milk vendor delivery milk delivery',
#  'possible get discount annually membership membership.',
#  'missing grouping inline urls long text many features others pointed text',
#  'seeker gone project project.',
#  'installed notion phone tried web version Notion',
#  'mean invideo not work mobile mobile',
#  'love notion desktop android apps slow frequently crash notion',
#  'used promo code annual business plan 90 final price system charged 15usd can help promo code',
#  'notionhq completely pointless make dashboard looks distorted iphone dashboard',
#  'can something like done notion especially subscription multimple google calendars one overlaid tasks subscription',
#  'adere fixed route make delivery time daily fixed route',
#  'hello dear free trial trial',
#  'moment turn functionality not possible mobile yet however desktop app web find option selecting list items click block handle select turn list list',
#  'function would good add dark mode dark mode',
#  'line discount coupons can send yr loyal customers discount',
#  'delivery boy never puts milk bag milk',
#  'timely delivery service products available delivery',
#  'can not make image text exampple one line text',
#  'really like features notion can used devices enables toggle mode save space notes many functions especially export pdf makes convenient notes',
#  'product team largely ignores feature requests instead providing long work arounds team',
#  'one app app.',
#  'new timeline feature something waiting eagerly since great tool able keep track progress project project.',
#  'since offers get 400 onetime payment massive 50 discount discount',
#  'happy services rendered far services',
#  'make template gifs canva client portal notionhq launching soon launching',
#  'can start free plan upgrade business plan free',
#  'okay missing whole bunch great features websitemac os app can Mac',
#  'way not pay anymore pay',
#  'ah ok look layers panel text locked unlock text',
#  'stick raw text files text',
#  'not even open app offline app offline.',
#  'customer service n quick delivery Customer service',
#  'today asked login mobile mobile.',
#  'improve payment technique payment technique',
#  'give russian language Russian',
#  'seriously best task notes management app task',
#  'always big fan project management can find good service tried airtable today project management',
#  'customer care service can better Customer care service',
#  'well video show click bottom right scene not scene',
#  'quality fruits veges low grade unhygienic Quality',
#  'thanks restoring old inbox view inbox',
#  'notionhq would awesome could mark images paste images',
#  'uploading brand logo also nothing logo not added Logo',
#  'originally planned use asana list tasks found project management capabilities amazing list',
#  'can look could share name domain workspace workspace',
#  'comprehensive knowledge management system app ever used app',
#  'mean lower text overlay covered overlay text',
#  'ok finished editing editing',
#  'even higher authorities not look customer complaints customer complaints.',
#  'great app storing notes takes really long time open application phone app',
#  'jim following progress since found weekly upda weekly',
#  'today installed notion app app',
#  'guys correct locales ukraine downloading application polish although previously everything correct downloading',
#  'notion amazing Notion',
#  'would like remove paid version paid version.',
#  'discounts promotions offers offers',
#  'add russian lang please give 5 5 Russian',
#  'grab free notionhq template f template',
#  'app great really slow not look smooth desktop App',
#  'best app organization ever app',
#  'features access 3500 curated templates full access image library full access standard video library 120 istock images videos free access creator clubs premium templates images',
#  'even know get plan plan?',
#  'intelligent tool organizing tasks managed combine efficiency humanize hot girl efficiency',
#  'pricing page says cloud storage unlimited 100gb pricing',
#  'widgets loads slowly android phones android phones',
#  'also can add varieties vegetables varieties of vegetables',
#  'suggest 1 one step clear trash 2 enter photo column table Trash',
#  'use collage notes collage notes',
#  'even update app not load faster app',
#  'please put dark mode dark mode',
#  'worked long hard chart family heirlooms quilts cooking fork paper weight candle sticks books photo albums disappear update chart',
#  'many things can include calender check list data table videowebsitephoto links galleries video/website/photo',
#  'promo code not able redeem promo code',
#  'point charging supr user taking 99 rs items stock stock',
#  'mobile experience could little better coming pc mac formatting fine Mobile experience',
#  'notionhq formula taking long notion not responding formula',
#  'hard trim video video always hang especialy big file video 46 minute length video trim',
#  'account individual access different email password account',
#  'phdgeek mainly youcan customise notionhq hell import everything share specific bits share',
#  'not desktop version desktop',
#  'can make transition russian half russian half english Russian',
#  'every change made not get saved saved?',
#  'used filemaker pro years FileMaker',
#  'video not uploading video uploading',
#  'can see numbers pdf print can cross pdf',
#  'cannot select multiple items app super easy website app,',
#  'prioritize tasks tasks.',
#  'app great takes forever open App',
#  'not opening shows logo centre centre',
#  'can pls provide item within 5 6 provide the item within 5 to 6 am',
#  'cut scene half scene',
#  'getting customer centric customer centric.',
#  'found app became compatible siri shortcuts struggling connect shortcut reached developers assistance app great everything could hope totally user friendly simple streamlined also capable handling complex intricate applications well also cross platform can truly accessible back story met promptly loads help responded well deserved praises given swag sincere hand written thank say not everyone reaches get frustrated get response point important company people created done knowing user help catapult company forward exactly done create amazing product ensuring runs smooth sucheta rock thanks help best wishes Totally user friendly',
#  'going onthere serious issues using software incognito window notpreviews not loading editing trim video function previewing videos missing clipswhen can expect addressed loading,',
#  'not even open stays white screen notion logo notion logo.',
#  'customer care service much bad customer care service',
#  'time delivery communication delivery',
#  'can find video learn use fade inout music how to use',
#  'copyrightfree music reseller rights advanced editing Reseller',
#  'possible get refund cancellation refund',
#  'wish ipad app good computer app IPad app',
#  'please add widget android well widget',
#  'can generate video facebook ads facebook story ads instagram video ads instagram',
#  'need improve quality products delivered quality',
#  'long take refund money refund',
#  'referring annual plan 120 10 month 20 96 8 month plan',
#  'add widgets would 5 stars widgets',
#  'well using app application started not open good app',
#  'chartered financial analyst workspace name workspace',
#  'chose 7 different passwords different combinations avail passwords',
#  'business plan 1 mth free trial trial',
#  'guys not use email bank account used refund email,',
#  'recently switched using notionhq literally everything writing task management project planni switched',
#  'not happy delivery charges 2 rs subscription amd 20 rs single item delivery charges',
#  'needs functionality similar gmail instagram can monitor Gmail',
#  'yes can export 60 new videos every month export',
#  'customer service terrible keep getting run around one gives accurate answer Customer service',
#  'can please help give access istock clips access',
#  'really love notion buggy android app major set back android app',
#  'try cancelling website ended not going cancelling',
#  'app great planning organizing tasks organizing tasks',
#  'see went 50 50%',
#  'please add variety leafy vegetables variety of leafy vegetables',
#  'video 2 scenes render finished 2nd scene music scenes,',
#  'notion huge potential however not point yet Notion',
#  'best app category app',
#  'article use invideo how to use',
#  'timely delivery good customer care Timely delivery,',
#  'atleast 510 discounts available regular subscribers discounts',
#  'business even use work business',
#  'promptness good response queries problems response to any queries',
#  'objective exporting filter view able select clients export csv order send mass email send caller make appointments csv',
#  'need delivery time time delivery',
#  'orders confirmed not delivered Orders',
#  'comfortable trackerboard board',
#  'feature rich app app.',
#  'new update took away ability swipe tasks deletecompletereschedule tasks',
#  'monicalimco mashcroft notionhq roamresearch use notionhq web clipper visit course web',
#  'notionhq trying sign using student email not receiving temporary sign code sign up',
#  'great tool tool.',
#  'app not load app',
#  'nice app however would like request zoom feature mobile users let us zoom photos app',
#  'every time try edit page create link tools keyboard flash half second close back edit',
#  'adding new music music',
#  'please waive delivery charges delivery charges.',
#  'ui ipad pro joke Ipad',
#  'unlimited storage multiple brand presets Storage',
#  'click link like youtube instagram link open browser instead app app.',
#  'can overview projects together keep track everything runing smoothly however think still lacks key features would awesome could implement make nicer useful tool however,',
#  'instead one notetaking app tries everything using suite notetaking apps serve differen notetaking apps',
#  'really want stop billing subscription subscription',
#  'hi created workspace would like guests invited consult material not edit workspace',
#  'excellent prompt service Excellent',
#  'please optimize app android android',
#  'use company company',
#  'refunded payment cancelled subscription cancel',
#  'journals gtd cookbooks whatever GTD,',
#  'guys charging delivery fee worst thing delivery fee',
#  'really good app thank thank much team work design app',
#  'best app ever app',
#  'really helpful templates project bases sample data makes sense potential uses Really helpful templates',
#  'like teal colour not stripy background colour',
#  'can look could share url name page URL',
#  'priority not displayed mobile versions zb priority',
#  'haptics sound design responsive gesture animation like drug Haptics,',
#  'app however terrible app',
#  'order 11 receive 7 Order',
#  'screenshot speed test upload speed 0 load',
#  'device unfortunately limited android 6 however android 6,',
#  'notion awesome tool Notion',
#  'soon open app stays logo white backgroundplease help know great app logo',
#  'seems like notionhq bug tweet embeds bug',
#  'used managing various tasks group group',
#  'app much less interesting comfortable use web version bad web version',
#  'notionhq finally addicted moved spreadsheets doc organised everything organised',
#  'stopped using ios note onenotes go app soon turn ipad IOS Note,',
#  'hey remove build scene actually drag uploads timeline drag',
#  'prompt delivery daily basis understanding requirement customers specially vacation featuredy vacation',
#  'many bugs latest version bugs',
#  'using organisation itinerary craft items working like dream craft',
#  'application not work employeeteam tags not always loaded necessary ones tasks not load new comments makes impossible track progress task team',
#  'edit background text box text',
#  'please enable multicolumn layout ipad drag drop text editing part desktop counterpart drop,',
#  'delivery charges rubbish schemes delivery charges 90 rs charged milk delivery house Delivery charges',
#  'want make sure fits needs purchasing purchasing',
#  'would like start taking advantage features enterprise right away namely setting seo separate pages actual workspaces ef overarching space workspaces',
#  'workspace name myspace name page ji lu ju dian ying workspace',
#  'idea assume occurs paste video gif paste',
#  'put computer timeline timeline.',
#  'latest update longer works certain ipads iPads',
#  'popping bit back later popping',
#  'barring items onions tomato potato quality product supplied good potato,',
#  'please change emojis android please make animation pf opening closing pages smoother android android,',
#  'can remove team member team',
#  'meeting coworkers notionhq office first time ever zooming 1 year g first time',
#  'early morning delivery morning delivery',
#  'little bit behind apps widget scene widget',
#  'note making experience unparalleled Note',
#  'either android ios windows laptop iOS',
#  'irregular deliveries every month deliveries',
#  'think notion good app note personal database little complicated public person app',
#  'good milk delivery milk',
#  's6 lite struggling simple things like deleting lines menu keyboard S6 Lite',
#  'resetting notion resetting',
#  'notionhq update evernote imports Evernote',
#  'ios app lot restrictions justified not iOS',
#  'service excellant keep Service',
#  'fruits like apple Fruits',
#  'initially guys promoted free delivery charges charges taken packet milk disappointing milk,',
#  'refunded payment cancelled subscription refund',
#  'pictures slides slide separate picture right corresponding notes slide one long text block picture)',
#  'list item short item',
#  'notion vastly powerful average notes app many excellike features really impressive can achieve notes app',
#  'love design look app modern app,',
#  'bad customer care unstable unreliable application high delivery charges customer care,',
#  'hi tried upgrade account account',
#  'not like phones slow anything app optimization app optimization.',
#  'download youtube upload add scene youtube',
#  'well not see option try editing though editing',
#  'not look like care much ios version can not really use confidence so I',
#  'also remove delivery charges delivery charges',
#  'switch notionhq roamresearch switch',
#  'im learning useful intuitive works well tremendous contribution subject dates could include dates dependent date another task changing one changes dependent dates eg date task date x 5 5 days dates including previous later business day include startend date ranges Dates',
#  'think work can wait minutes download check download',
#  'copy memo works copy',
#  'milk delivery good regular Milk delivery',
#  'bc account needs pricingmodel pricing',
#  'need able make task public phone right can make public desktop mine bit phone',
#  'costumer support not responding milk not delivered everyday milk',
#  'can use 10 istock media month iStock',
#  'app great supports everything can webdesktop versions notion app',
#  'service bad availability products poor Service',
#  'open asana ipad always asks update update ask update update',
#  'cant open flashlight using barcode scanning function function',
#  'review disappeared works quite well offline functionality terrible offline',
#  'one support centre knows going deliver milk not even number morning 7 milk',
#  'not even get email notification site notification',
#  'troubling times would like products delivered however service erratic service',
#  'can see audio volume not background music background',
#  'certain items not available purchase week items',
#  'really like pc apps mobile version needs much optimization improvement mobile version',
#  'helped cofound company notion difficult task manageable task',
#  'want edit 2 videos one screen edit',
#  'long time open trash app APP',
#  'however one negative thing believe crucial can not select text 1 block 1 block.',
#  'however not see way add custom templates notion without submitting global notion template gallery Gallery?',
#  'love blocks feature ability use markup language code mathematical expressions code,',
#  'able see shared page shared notion pages team plan person owner page also member team plan shared',
#  'not business plan correct Business plan,',
#  'trying remove account account',
#  'however not see way add custom templates notion without submitting global notion template gallery templates',
#  'found airtable great addition work space entertainment spheres work space',
#  'notion incredible desktop unusable android app takes 70s move beyond splashscreen Android',
#  'not load tried incognito mode chrome new browser chrome',
#  'can help make weekly schedules lists pages subjects helpful templates upload files take notes notes.',
#  'favourite note app app.',
#  'can not get previews load whether istock videos yur library istock',
#  'android app way slow good Android app',
#  'also want add personal column without affecting original can column',
#  'thought would love ipad using magic keyboard however many limiting bugs prevent keyboard digital physical utilizing pieces software iPad',
#  'delivery charges subscription charges insane not subscription charges',
#  'try share link groupmate can not get access share',
#  'app good issues nothing thing urge developers add handwriting notebook featire templates would blessing App',
#  'packing staff unskilled tomato mausambipodina kadi patta 20 wasted Mausambi,Podina,',
#  'excellent time bound service Excellent',
#  'inline gallery view not toggle bug usually happens card medium size gallery',
#  'not need right subscribe start using subscribe',
#  'exelent app helped get notes ideas place notes',
#  'click profile icon top right go projects page 3 project',
#  'sorry logged not get link anything may sent meanwhile logged',
#  'prompt delivery good products extra charges delivery easy contact customer care service easy add deduct products app easy load money wallet wallet.',
#  'wanted tell hard get name parameter table locked entire name parameter not fit column name table',
#  'hey recently asked refund effect refund',
#  'reason gave 4 stars notion not widget android android.',
#  'work project manager things hard way years spreadsheets organizational aides took long put together actual project project',
#  'add paytm food wallet option one payment options Paytm Food Wallet',
#  'not need buy separate plan one one account simply add team members get benefits account',
#  'best productivity app productivity',
#  'edit implemented correct views mobile mobile',
#  'automated text speech Text',
#  'remove service charges service charges.',
#  'meantime workaround might help export files directly evernote import notion Evernote',
#  'okay know notion template library filled general use templates templates',
#  'add stuffs stock stock.',
#  'instructionstutorials beginners using site beginners',
#  'cancelled delivery not receive amount delivery,',
#  'easy use keeps super organized ORGANIZED',
#  'one item not delivered 3rd sept information givennor refund item',
#  'honestly best note taking app app',
#  'phone version lacks essential feature without quite useless web clipper android Android.',
#  'time track forestappcc project track notionhq invoice google doc template Invoice',
#  'resubscribe button resubscribe',
#  'lot people asking customizable color options timeline view timeline',
#  'total stars 35 stars 3/5.',
#  'can also please share email upgrade plan upgrade',
#  'capability simple things like editing functions ie calculations kanban views pivot tables calculations',
#  'not interested premium lifetime plan lifetime',
#  'hello can cancel free account cancel',
#  'please continue work mobile app app.',
#  'concerned account compromised account',
#  'vistaplus workspace Workspace',
#  'resubscribe button button',
#  'account lethargy yet receive refund amount office till date refund',
#  'offers cashback promotions product discounts starting given discounts nothing watse cashback promotions',
#  'hopefully among plans someday application reach web version functionality stop useless web version',
#  'one area app fails app',
#  'prompt delivery fresh product unadulterated best app recommended family friends keep Fresh',
#  'one main principles gtd todo list one place seems simple much benefit todo list',
#  'bookmark chrome pages across accounts whenever browsing one account click bookmark links page account encounter error Chrome',
#  'work team uses airtable project management recently begun using new agile workflow workflow',
#  'refunded payment cancelled subscription subscription',
#  'interface desktop fave desktop',
#  'plan cancelled not charged 4th may plan',
#  'professional service prepaid delivery prompt redressal complaints quick refunds Refunds',
#  'can look could share url name page share',
#  'could ipad overwritten work would done online iPad',
#  'apologies templatespecific effect template',
#  'larshofstetter christi build proper relational databases efficiently codahq databases',
#  'promptness ontime price Price',
#  'free plans not even watermarks free plan',
#  'found allow support access feature appreciate much Support',
#  'honestly not great app compared desktop version desktop version',
#  'insert block list needs searchable block list',
#  'morning time delivery doorstep delivery delivery',
#  'need worry start supporting languages besides english line English',
#  'sure can apply code get trial plan plan',
#  'app could better mobile interface gesture integration quick actions widgets widgets).',
#  'notes stored local vault dns issues notes',
#  'app must support androids multiwindow api would better tablets resize app screen Androids',
#  'says not connected internet not work internet',
#  'hi uploaded video made youtube copyright claim music music library upload',
#  'appear video exported exported',
#  'apples bananas notion ios appi want convert list todo list inside block page Apples',
#  'problem password password',
#  'one best project management systems date business tried date',
#  'sorry trouble accessing workspace workspace',
#  'keep seeing notion icon forever Notion icon',
#  'restart app every entry scrolling gets stuck trying enter data scrolling',
#  'punctuality good follow Punctuality,',
#  'easy way see templates made across org templates',
#  'cash dilivery price items dilivery',
#  'prompt delivery friendly customer service delivery',
#  'loved wunderlist simplicity ease use microsoft bought ruined look something else tried 6 options came across asana love bought',
#  'app versatile recently seem updated like desktop landscape mode ipad app',
#  'hi matt apologies trouble exporting workspace workspace',
#  'recently switched notion not aware bad works android Android.',
#  'may still integration point yes thought nice integration',
#  'timely prompt service service',
#  'offers google sign not apple Apple',
#  'airtable standard tool work chose something useful create interface c era numerous companies built wonderfully polished productivity tools ipad web platforms iPad',
#  'see used 14 day trial not cancel subscription side thus charged charged.',
#  'shared workspace specific channel specific notionhq slack integration game changer Shared',
#  'idea split database database',
#  'change text box color color?',
#  'table one column confluence page table',
#  'notion incredible Notion',
#  'recurring task times automatically set hour earlier time changed task',
#  'can recommend staying save half money compared monthly plan monthly plan costs 20 per month 240 year yearly plan 120 comes 10 month plan,',
#  'sure ill mail lifetime plan offer directly can get back plan',
#  'failed export project project',
#  'hi notionhq can pls adopt google calendars bar thing let us know time google',
#  'languages near future languages',
#  'takes minutes load page nevermind whole app flagship phone app',
#  'order flexibility attentive response response',
#  'page permissions workspace name page name keywords urls alternate emails web sessions login method page url web sessions account 1 support access granted workspace',
#  '50 highest got good deal honest decide go lifetime unlimited plan pay get unlimited access life would happy honor 50 discount lifetime',
#  'dear developers logging program using google account returns error window account',
#  'time delivery prompt service last minute orderskudos service',
#  'can upgrade businessunlimited plan use upgrade',
#  'gt want learn future whether team something wrong whether teammate accidently deleted file gt therefore would good get mailadress kaiser got hacked whether failure notion system learn',
#  'already logged student email macbook Macbook',
#  'best productive app ever seen app',
#  'know workspaces card card',
#  'timely updates case product not delivered getting delayed Timely updates',
#  'render compose alright render comes places little smaller render',
#  'can ensure linked purchase make purchase',
#  'billed service months cancelled trial billed',
#  'heard good things app wanted try app',
#  'let try browser browser',
#  'hello trying free trial invideo happened forget today day going charged would like cancel subscription gat refund please trial',
#  'editing story instagram pinterest small Pinterest',
#  'hi kate downgrade account free version free',
#  'best app ever app',
#  'encountered irritating problem using app every time type cursor keeps going back cursor',
#  'excited list companies admire work everyday list',
#  'click reading notes table reading list id like direct directly page reading note table',
#  'finally usable mobile due faster startup time startup time!',
#  'iput card details card',
#  'give blur effect changing scenes blur',
#  'charging milk much than',
#  'refunded payment cancelled subscription subscription',
#  'apologies premium videos never part appsumo plan AppSumo',
#  'love platform app takes long time load app',
#  'open regardless not taking advantage force touch quick note capturing not clear button trash etc button',
#  'excellent time service time service',
#  'can save draft can not share draft export save',
#  'iphone app not open 05 iPhone app',
#  'wonderful app makes keep track thesis work app',
#  'hard use mobile use',
#  'attachment screen recording 20210502 41927 pmmov Recording',
#  'received desktop app email interested point supported win mac desktop',
#  'app get want organise thoughts list whatever throw notion would able app',
#  'best note taking services note taking services.',
#  'want type text field long text rich text formatting can see typing field',
#  'asana improved productivity productivity',
#  'insulated bag promised insulated bag',
#  'upgrade monthly yearly yearly',
#  'honestly love app app',
#  'support section app needs improvement Support section',
#  'stock availability quality veges fruits pricing service fees pricing,',
#  'eg delivery guy tries substitute amul cow mother dairy cow tries to',
#  'would literally love provide widget not bother open app many times app',
#  'prompt service kn time delivery service,',
#  'dear developers make desktop chrome dropdown list employees selecting comment field list',
#  'calendar view databases also ultra limited can not see properties click get databases is',
#  'app massively improved past year pc version godsend PC version',
#  'problem push exported pdfs github contents pdf lost PDFs',
#  'works pretty well time often fails upload photos especially taken app instead camera app built upload',
#  'app doesnt launch miui global 12 android 9 Android',
#  'tried remove password settings password',
#  'spent 30 years dba not going expect raw power mariadb oracle little shared synchronized database airtable treat use database',
#  'love airtable able log app using google authentication Google',
#  'free version useful free',
#  '5 stars add custom filters app without confusing use filters',
#  'milk curd delivery excellent products delivery like sweets snacks vegetables etc vegetables',
#  'refunded payment cancelled subscription cancel',
#  'use app scheduling journaling many different things journaling,',
#  'loving app far going daily driver everything bug app',
#  '3 days experience 1 day got product door step product',
#  'great tools glitchy phone ipad hoped would better phone',
#  'workspaces stay consistent c workspaces',
#  'workspace domain workspace',
#  'however hide sidebar switch full screen text shifts meaning not align corresponding slide picture screen,',
#  'currently not way expand lines described possible future line',
#  'serious crash ipad ios 12 can not use Serious crash',
#  'template coming tomorrow Template',
#  'x8664 web clipper plugin version web clipper',
#  'hello swapnil charged today 360 messaged yesterday cancel free trial free',
#  'excited use app highly recommended makes completely unusable app',
#  'newest update 41 renders date field almost unusable field',
#  'complete project would like duplicate including content backup backup.',
#  'paying team subscription account workspace created workspace',
#  'amazing app app.',
#  'reliable service great customer service team customer service',
#  'yes trimmed ready go trimmed',
#  'deleted account need resend invitation accept account',
#  'app never opens app never opens',
#  "started using notion amazing thing would love mobile version would widgets would love use calenders widget's,",
#  'good service please include grocery well grocery',
#  'agree would great add global tags used inside page content shared engineering product team assist project prioritization planning tags',
#  'appsumo lifetime account Appsumo',
#  '722 pm gmt2 wrote hello reaching not tax number valueadded tax vat number goods services tax gst number file number file invalid file',
#  'yesterday clash video background music music',
#  'first scene bottom video select mute fine mute',
#  'finally able finish project would not save continued crash save',
#  'please provide bag supposed used keeping dairy cool bag',
#  'slow interface loading time interface',
#  'dark mode android app android',
#  'preview link downloaded video preview',
#  'love app use lotion linux version notion notion app can used together sync data write notes notion app',
#  'delivery service missing items order missed items not rearrange fruits vegetables bad quality fruits',
#  'samsung notes bublup app messages app handy recognition Samsung',
#  'would totally agree would great useful feature allows ability create columns inside toggle feature create columns',
#  'see turn music scene scene',
#  'ease ordering timely delivery best part can use vacation option not homea suggestionshould increase variety products sold vacation option',
#  'excellent tool crucial features good task resource management experience tool support excellent fast assertive team happy congratulations asana Fast',
#  'created notion account using school email thought would automatically upgrade personal pro plan not school',
#  'stop charging delivery fee milk packets delivery fee',
#  'laggy freezes device snapdragon 855 laggy',
#  'desktop experience great though Desktop experience',
#  'basically cost unlimited yearly plan get life never pay single penny plan',
#  'ok apply let know downgrading business plan not certain features appsumo plan like premium media limited 10 min videos premium',
#  'notion shines desktop version becomes mobile version Notion',
#  'annoying dark mode apps updates apparently made dark mode toggle go away updates brought back dark mode',
#  'app works great could please please add audio alert audio',
#  'subscriptions provisioned perworkspace basis would pay wanted another workspace enterprise plan workspace',
#  'bug add tag not working android Tag',
#  'prompt hazle free ordering Prompt',
#  'plan appsumo watermark remover watermark',
#  'app stuck loading screen App',
#  'not let load clip scene load',
#  'great organizational tools working team remotely not team',
#  'avoid belated delivery milk delivery of milk.',
#  'awesome app please please can make widget allow see lists stuff today week etc like microsft would make app perfection widget',
#  'ios version limited showing simple row grid view see screenshots can make access gallery view grid view row picture end kanban board etc iOS',
#  'using shared database yep shared',
#  'colleague paid subscription get claim paid',
#  'beware coercive subscription model subscription',
#  'apologies cannot copy element clip one project another copy',
#  'android version nest bugs Android version',
#  'can share screenshot loading loading',
#  'kentboogaart notionhq desktop app normally much better web app Web',
#  'see fit blur black bar can add shape color set behind blur',
#  'proper transaction history poor app quality wrong delivery shown app bad service service',
#  'name class notes think notes',
#  'like notion lot app start time terrible white loading screen blindingly bright seems dark mode gone completely screen',
#  'would love change 5 review can get working like desktop app desktop app.',
#  'could one users access beta program Beta',
#  'still trying figure music music',
#  'tried use app upload file get attachment column table open attachment',
#  'page permissions workspace name page name keywords urls alternate emails web sessions login method page url web sessions account 1 support access granted URL',
#  'app response poor support process gone bad product costs high options rescheduling subscribed products delivery end subscription App',
#  'deliver milk milk',
#  'else can go business yearly plan 40 discount 90 75 month business',
#  'love notion ipad app keeps features desktop totally functional everyday updates notetaking app',
#  'drag video canvas show trimmer trim',
#  'delivery avin milk packets undepedable Avin milk packets',
#  'went sign would not let proceed picking password password.',
#  'yeah time vegetables fruits quality also good situation keep thanks giving us necessary items lockdown quality',
#  'switched obsidian still use notion switched',
#  'oh ok thank please can tell details lifetime lifetime',
#  'purchased plan would like activated please purchased',
#  'sadly not possible alter column widths mobile device therefore renders application totally useless mobile',
#  'taking forever delete scene scene.',
#  'packing delivery breads cakes bad breads',
#  'can use code bradx25 get 25 discount subscription plans plan',
#  'can not seem make run phone oppo a37f Oppo A37f.',
#  'first company running h kealth workspace using okta saml provider sso scim SAML',
#  'better routine daily weekly monthly annual reminder calendar schedule makes app perfect app',
#  'best note taking app used years app',
#  'however not see way add custom templates notion without submitting global notion template gallery custom',
#  'think bg music slider affects volume scenes music',
#  'reduce service charges provide daily super bag committed daily super bag',
#  'perfect wanted know change invideos plan afraid wrong plan looked bill 110 bill',
#  'reliability low reliability',
#  'discovered app looking productivity section trying look something help university struggling keep motivated productivity',
#  'hi could sync easy move evernote files10yrs notion sync',
#  'pay attention customers complaint resolve immediately customers complaint',
#  'would like downgrade account temporarily business free not using moment business',
#  'send fresh vegetables not rotton delivery executives properly trained website customer friendly website should be customer friendly',
#  'proper reply chet supr bag last five months multiple complains supr bag',
#  'doesnt hold settings settings',
#  'best app team assignments team',
#  'notion app call log busy times incredibly helpful keeping top calls jobs notion app',
#  'separate paid account paid account?',
# ...
#  'would love able calculate total time bottom column column',
#  'delivery time delivery charges delivery charges.',
#  'company team can update process task summary things one application really convenient task',
#  'improve management suprdaily suprdaily.',
#  'hi cancelled subscription days ago yet still charged yearly fee yesterday subscription',
#  'think able access notes notes',
#  'download tell asana keeps failing let know app lousy service thank Download',
#  'notion productivity tool awesome Notion',
#  'easy simple can also complex database solutions database',
#  'thank updating option view larger photos view',
#  'simple useful app multiple online coworking tasks working tasks',
#  'rather entire image black image',
#  'hi problem plan supposedly premium plan however never select plan wish free plan premium',
#  'not let load clip scene scene',
#  'best practice work small scenes say 20 seconds instead longer 60 second scene scenes',
#  'freezes even small base mostly good app often hangs regaining system focus even small base tables dozen records attachments records',
#  'app brilliant structure alevels life around app structured aesthetically pleasing use app',
#  'talking transitions like maybe video turns page scenes blurs scenes things like scenes',
#  'overall awesome app worsened features latest versions well stupid missing ones android versions android',
#  'many times find vegetables delivered underweight complaining said sorry vegetables',
#  'app good like many ios limps since need able use views offered os x views',
#  'used coupon code none history app could figure got vanished none agents could track guys wanted keep snapshot coupon code applied coupon code',
#  'meantime please note desktop apps currently running bit faster using notion web browser web',
#  'practical organizing tasks connecting team well stimulating productivity large scale connecting',
#  'really want like app ipad version major usability flaws especially databases iPad version',
#  'found app accidentally easy use make mind mapping using bullet points generate app',
#  '100 customizable whatever needs many options views templates tags menus tables lists elements useful many things can not even list menus,',
#  'always hated ms excel EXCEL',
#  'new updates lost ability add new anything button bottom page gone new updates',
#  'worst service till not provided bags outside room due Worst service',
#  'early morning quick respone milk supply boys also sincere milk supply',
#  'different trello not convenient mobile version not see subtasks description task subtasks',
#  'windows version seems great still seems bugs missing features mobile version bugs',
#  'would like adjust resize remove background etc remove',
#  'used use apples built reminders app Apples',
#  'get back mail ill help make payment put lifetime plan directly pay',
#  'notionhq little unclear guests free paid plan Guests',
#  'got notion devices homeowners policy said download app install notion devices app',
#  'reason gave 4 stars notion not widget android widget',
#  'best app managment tasks notes think mobile app not fast could improved app',
#  'additional info can share us help verify share',
#  'long product list availability poor availability',
#  'service excellent key features available online missing app online',
#  'service executive behaviour Service',
#  'can highlight one line time one line',
#  'not email verification code email',
#  'features app best found anywhere till date app',
#  'removing delivery charges giving offers delivery charges',
#  'keeping adequate stocks keeping away short fall stocks adequate stocks',
#  'thing would make better would todo list widget home screen widget',
#  'notion worked time stops loading screen Notion',
#  'really love design functionality app app',
#  'app great App',
#  'put transparency image image',
#  'google login incognito not work INCOGNITO',
#  'crashes setting loading setting',
#  'app great app',
#  'app repeatedly crashes changing filtered view ios view',
#  'awesome app app.',
#  'click group can edit animation whole group animation',
#  'better customer service help customer service',
#  'not want get charged time charged',
#  'good response delivery charges good quality products no delivery',
#  'cant load data linked records linked',
#  'happy pay 400 pay',
#  'switching com switching',
#  'please not hesitate drop us line whenever need help drop',
#  'give android widget give 5 star Android widget',
#  'hello create task attach pdf pc wont let open app pdf',
#  'overall good experience lack offline mode sucks offline mode',
#  'quick efficient delivery quick response refund nondelivery nonavailability items non-availability of items.',
#  'great application denying recently started getting laggy glitchy made uninstall app application',
#  'app functioned well first time opening load times absolutely ridiculous point cannot even access App',
#  'could upload 3 seperate video files mash one final video upload',
#  'less free version enough features work projects free',
#  'aprilynnea notionhq make first database get back Database',
#  'want cancel plan plan',
#  'love sortable looks much nicer tables easy learn gets excited using databases sortable',
#  'promt service hasselfree delivery delivery',
#  'heres suggestion remove app app store enable progressive web app support asana website website',
#  'guest member guest',
#  'app lots functions complicated functions',
#  'prompt reliable extra cost cost.',
#  'supr daily bag not provided assured time joining Supr daily bag',
#  'put none animation still slide left right slide',
#  'actually content free version get plan pure respect notion provided studying creative processes Notion',
#  'cancelled cancelled end period ie 3rd june cancelled',
#  'appthis app looking app',
#  'looks like timezone can not changed database locked database',
#  'shows notion logo Notion logo.',
#  'excellent service please provide types vegetables reasonable rates rates',
#  'easy take notes reference notes keep track projects love accessibility computer tablet phone accessibility',
#  'required internet launch apps Required',
#  'evernote really struggled nail cross device workflowsyncing extra stuff not matter device workflow/syncing',
#  'excellent app note taking cross platform usability app',
#  'can kind database templates template confined database database',
#  'failed export project export',
#  'gave spin daily habit tracker adds lot insights user daily',
#  'amazing application plenty offer even free version can almost finish 8 hour shift app opens application',
#  'sheher design amp operations manager Design',
#  'vatgst number not required tax jurisdiction tax',
#  'app amazing doubt app',
#  'notion team notionso allinone workspace notes tasks wikis databases workspace',
#  'paying ate time 5 usd month pay',
#  'guess could not use commandp search content inside table personally like put description remarks table could see information without opening page using table databases notion opening',
#  'video longer 15 mins take longer export export',
#  'best notetaking app could ask app',
#  'although complicated first many functions quite complete even free version free',
#  'much pratik follow email email.',
#  'can pay subscription subscription?',
#  'app stuck splash screen app',
#  'use firefox entirely reason stopped working Firefox',
#  'make error trying log log',
#  'hello recently purchased business plan 50 promo code year Business plan',
#  'cancelled back free account cancelled',
#  'best notes app ever use app',
#  'can invideo upload directly youtube without first download computer YouTube',
#  'useful note app ever seen app',
#  'not cool notepad quick notion not notepad',
#  'stupid app doesnt notify subtasks notify subtasks',
#  'simonw joshu move recipes notionhq evernote gotten horrible past couple years recipes',
#  'recently bought new ipad thinking experience would good bitterly disappointed see basic functionality like selecting drag dropping items severely lacking functionality',
#  'discovered airtable last week testing love easily customisable replaces reliance spreadsheet maintain inventory issue app limited can duplicate record frustrating purchase 20 different things supplier date etc means either duplicate record desktop case use app manually enter information 20 times incredibly frustrating another gripe can customise first column base freeze first two columns picture important inventory need either customise first column allow addition picture freeze first two columns scroll across can relate information exact item freezing columns available desktop version not app means constantly scroll back forth limitations app inability select multiple records deletecopy lack gallerycalendarkanban view exasperating previous two mentioned shame desktop version airtable incredible tool versatile ios app restricted talking desktop version give 5 stars ios app gets 3 Freezing',
#  'keep backups code backups',
#  'really tough reply someones comments comments',
#  'sometimes drag drop video suggestion advising make fits exact length text sometime guess text,',
#  'mean remove background image means able remove watermark watermark',
#  'use app everything expenses asset management Expenses',
#  'would nice able sort tasks calendar mode sort',
#  'got problem adding images istock images',
#  'colleague used one templates make youtube intro outro video template',
#  'floating table content Table',
#  'dont understand track time mobile app mobile',
#  'use lot would enjoy not block io much block',
#  'good service useful covid19 safe home service..',
#  'would mind sending workspace name billing email address file workspace',
#  'stuck loading page progress stuck',
#  'please make delivery charges free grocery milk grocery',
#  'browser use asana daily love browser',
#  'slow opening widgets widgets',
#  'url 2021nyeon URL',
#  'hi would like point takes really long time export download video export',
#  'angezanetti airtable notionhq gumroad would add tweet interesting things learn connect learn',
#  'video duplicated 4 media duplicated',
#  'love design look app modern app',
#  'hi notion currently build okr page team used relations databases database',
#  'unable copy text notion paste somewhere else paste',
#  'prompt delivery ordering support ordering',
#  'please update stock regularly items usually stock stock.',
#  'typeoneerror notionhq obsdmd could sync notionapi sync',
#  'seems really useful crushes every time try get card details like baloon adventures san francisco card',
#  'right can use chrome Chrome',
#  'making copies elsewhere reset desktop app see fixes desktop',
#  'poor functionality write edit longer texts write',
#  'says rendering can duplicate project another dimension duplicate',
#  'miriamgonp notionhq yo lo voy registrando en una tabla de logros voy anotando los reconocimientos una',
#  'needs tablet mobile update useful update',
#  'great tool ill put 5 stars include task reminders show notifications cell phone cell phone',
#  'app doesnt let log without sharing contacts log',
#  'single one time purchase 4900 60000 features included 30 videosmonth unlimited team members 1200 handcrafted templates standard media library video length 10 minutes Unlimited',
#  'exactly needed organize process organize',
#  'help paying paypal PayPal',
#  'important tools digital ecosystem time blocked gcal blocked',
#  'got problem adding images istock istock',
#  'quite disappointing see ipad way see timeline portfolios project portfolios',
#  'love using product performance criminally bad performance',
#  'want delete account delete',
#  'gt want learn future whether team something wrong whether teammate accidently deleted file gt therefore would good get mailadress kaiser got hacked whether failure notion system file',
#  'waste hours figuring use app app.',
#  'add total cost list inventory inventory',
#  'practical control tasks remote computer simply intuitively remote',
#  'fact talking video picture dragged scene fit textscript text',
#  'really love notion recently app really slow animations lot glitches app',
#  'prompt delivery immaterial weather conditions delivery',
#  'times products not available ie regular milk also milk',
#  'new updated version app not working updated',
#  'best app ever combination powerful apps best tool documentation app',
#  'free can given access free',
#  'love airtable app totally pointless without gallery view projects image based view',
#  'ohh see upload speed low average upload',
#  'reduce products rates reduce service charges service charges.',
#  'hey notionhq exporting page ur app pdf huge margin side paperany way r pdf',
#  'stuck days without laptop gotten know ios app pretty well stuck',
#  'mobile phone can never set traditional chinese please pay attention mobile phone group Mobile',
#  'per scene music volume can not adjusted feature bringing soon may workaround volume',
#  'timely delivery needed worst customer support improve customer support,',
#  'please cancel plan let know plan',
#  'brilliant web app great mobile app add nothing put nothing mobile',
#  'clicking custom template button throws spinner not create new page like custom',
#  'going one app changes everything APP',
#  'excellent task manager Task',
#  'best app ever used till making notes app',
#  'gota know tools offer take best take practical visual notes perfect app tools',
#  'yes access using email password email',
#  'videos can 15mins change editing speed requirements speed',
#  'please deliver correct items ensure not damaged deliver correct',
#  'grocery early hours Grocery',
#  'would better can see project dashboard not show percentage project',
#  'slow load open ofc takes slow to load',
#  'eg export page titled test page html would get testpagezip contains file test page 7ddhtml wish test pagehtml file',
#  'best productivity app ever use definitely recommend app',
#  'turn dark mode dark mode',
#  'wish could rate app better cannot even get beyond sign sign',
#  'app saves everything servers cannot anything offline internet useless business useless server goes useless cannot find option export data csv format type access failure lose whether side side operate dropbox like feature local copy cloud copy exists dropbox disappear tomorrow would still files airtable close doors reason lose even temporary basis maintenance Dropbox',
#  'download video project barely finished site went blank work gone download',
#  '1 dolar 815 tl discount much can discount',
#  'hi want add logo logo',
#  'really like notion term can give 4 stars mobile app opens slowly notion',
#  'would like able use work mental health field referrals assignments coworkers community field',
#  'automated text speech Text',
#  'app deserve download app',
#  'mostly like delivery service delivery service.',
#  'dark mode needs black theme appearance dark mode grey makes unattractive dark mode',
#  'however android app not live expectations app',
#  'marcovrj jmelaskyriazi notionhq airtable base pricing doc makers people actually create docs pricing',
#  'clearly best note taking app ever used app',
#  'half ltr milk delivery charge 1 rs delivery charge',
#  'please grant support access using account used reach support',
#  'love app little slow compared apps like microsofts todo trello onenote etc app,',
#  'browser version great ios version meh glitchy slow locks frustrating iOS',
#  'please dark mode dark mode',
#  'prompt service service.',
#  'prompt professional service professional service',
#  'can refund annual subscription notion annual',
#  'costly Costly!',
#  'mabye archive not right word since not storage used things much alive workspace workspace.',
#  'android app pure garbage Android app',
#  'milk sending expiry day not even one day expiry milk 3times milk got spoiled Milk',
#  'free delivery became paid service fee milk products not acceptable immediately revoke delivery',
#  'ease use polite delivery people Ease of use',
#  'notification badges keep climbing number even archived everything archived',
#  'hi need cancel account cancel',
#  'customer support team worst Customer support team',
#  'building house germany asana sooo helpful planning projects projects',
#  '3 days not got milk delivery milk delivery.',
#  ...]

# %% [markdown]
# ## Importing Transformers Pretrained Models

# %%
from transformers import TFAutoModel
from transformers import DistilBertTokenizerFast
from transformers import TFDistilBertForSequenceClassification

import tensorflow as tf

# %%
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')

# %%
train_encodings = tokenizer(X_train,
                            truncation=True,
                            padding=True)
val_encodings = tokenizer(X_val,
                            truncation=True,
                            padding=True)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((
    dict(train_encodings),
    y_train
))

val_dataset = tf.data.Dataset.from_tensor_slices((
    dict(val_encodings),
    y_val
))

# %%
model = TFDistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased',
                                                              num_labels=3)
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['activation_13', 'vocab_layer_norm', 'vocab_projector', 'vocab_transform']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier', 'dropout_19', 'pre_classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Compiling the model

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate = 2e-5, epsilon = 1e-8)
model.compile(optimizer=optimizer, loss=model.compute_loss, metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %%
model.fit(train_dataset.shuffle(100).batch(3),
          epochs=3,
          batch_size=32,
          validation_data=val_dataset.shuffle(100).batch(3))
# Out:
# Epoch 1/3
# 1200/1200 [==============================] - 254s 212ms/step - loss: 0.1979 - accuracy: 0.9306 - val_loss: 1.1178 - val_accuracy: 0.7075
# Epoch 2/3
# 1200/1200 [==============================] - 259s 216ms/step - loss: 0.1415 - accuracy: 0.9519 - val_loss: 1.1503 - val_accuracy: 0.6825
# Epoch 3/3
# 1200/1200 [==============================] - 259s 216ms/step - loss: 0.1088 - accuracy: 0.9658 - val_loss: 1.3282 - val_accuracy: 0.7075

# %%
model.save('absa_training')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Dropout object at 0x000001CE4F902D00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Dropout object at 0x000001CE4FCEA4C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Dropout object at 0x000001CE5432B730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Dropout object at 0x000001CE543349A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Dropout object at 0x000001CE5433CC10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Dropout object at 0x000001CE54342F70>, because it is not built.
# WARNING:absl:Found untraced functions such as embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, transformer_layer_call_fn, transformer_layer_call_and_return_conditional_losses, LayerNorm_layer_call_fn while saving (showing 5 of 410). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: absa_training\assets
# INFO:tensorflow:Assets written to: absa_training\assets

# %%
model.save_pretrained("absa")
